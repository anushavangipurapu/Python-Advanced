# %%
import pandas as pd

df = pd.read_csv("../data/employees.csv")

print("Employee Data:")
print(df)
# Out:
# Employee Data:
#    id    name department   salary   age       city
# 0   1  Anusha         IT  50000.0  24.0  Hyderabad
# 1   2    Ravi         HR  45000.0  28.0    Chennai
# 2   3    Sita         IT  60000.0  26.0  Hyderabad
# 3   4    John    Finance  55000.0  30.0  Bangalore
# 4   5    Anil         IT      NaN  25.0  Hyderabad
# 5   6   Priya         HR  48000.0  27.0    Chennai
# 6   7    Ravi         HR  45000.0  28.0    Chennai
# 7   8   Kiran    Finance  65000.0   NaN  Bangalore
# 8   9   Meena         IT  70000.0  29.0  Hyderabad
# 9  10   Arjun    Finance  58000.0  31.0  Bangalore
